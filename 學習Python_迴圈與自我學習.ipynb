# %% [markdown]
# <a href="https://colab.research.google.com/github/will20090425-eng/ColabRep/blob/main/%E5%AD%B8%E7%BF%92Python_%E8%BF%B4%E5%9C%88%E8%88%87%E8%87%AA%E6%88%91%E5%AD%B8%E7%BF%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌟 第2週課程複習：變數與邏輯 ( if else )

# %%
# 初始化 Initialization：設定粉紅色盒子和綠色盒子的初始值
# "<=" 右邊結果，送到左邊， 簡化為 "="
X = 0 # 粉紅色盒子一開始是 0
Y = 0 # 綠色盒子一開始也是 0

# 運算：改變盒子裡面的數字
X = X + 2 # 粉紅色盒子裡面的數字 加 2 = 2
Y = X * 2 # 綠色盒子裡面的數字，變成 粉紅色盒子(2) 乘 2 = 4

# 輸出：檢查總和並印出訊息
sum = X + Y # 計算兩個盒子的總和：2 + 4 = 6

# 判斷式：根據總和的大小來決定印出什麼訊息
if sum > 7 : # 如果總和大於等於 7
  print("Sum 大於等於 7，我們下課") # 就印出這句話
else: # 否則 (如果總和小於 7)
  print("Sum 小於 7，我們繼續上課") # 就印出這句話
# Out:
# Sum 小於 7，我們繼續上課

# %% [markdown]
# ---
# #### **想下課，你來惡搞**

# %%
# 初始化 Initialization：設定粉紅色盒子和綠色盒子的初始值
# "<=" 右邊結果，送到左邊， 簡化為 "="
X = 0 # 粉紅色盒子一開始是 0
Y = 0 # 綠色盒子一開始也是 0

# 運算：改變盒子裡面的數字
X = X + 2 # 粉紅色盒子裡面的數字 加 2 = 2
Y = X * 2 # 綠色盒子裡面的數字，變成 粉紅色盒子(2) 乘 2 = 4

# 輸出：檢查總和並印出訊息
sum = X + Y # 計算兩個盒子的總和：2 + 4 = 6

# 判斷式：根據總和的大小來決定印出什麼訊息
if sum > 7 : # 如果總和大於等於 7
  print("Sum 大於等於 7，我們下課") # 就印出這句話
else: # 否則 (如果總和小於 7)
  print("Sum 小於 7，我們下課") # 就印出這句話
# Out:
# Sum 小於 7，我們下課

# %% [markdown]
# ---

# %% [markdown]
# 這是一份為您量身打造的 **「第三週：自動化與迴圈 (Automation & Loops)」** 完整教案與學生版講義。
#
# 自然組學生通常對「規律」和「數列」有極高的敏銳度。這週我們將把數學課學到的等差數列，完美轉化為程式碼裡的 `range()` 工具，讓電腦在一瞬間完成人類要畫幾百次的圖形，徹底展現程式設計「為了偷懶而發明」的核心精神！
#
# ---

# %% [markdown]
# # 🌟 第三週課程總覽：讓電腦做苦力 (For 迴圈)
#
# * **核心精神**：從「手動切片」進化到「自動批次處理」。導入 Python 的 `for` 迴圈與 `range()` 數列，讓學生體驗極致的自動化效率，並學習處理常見的「索引超界 (IndexError)」錯誤。
#
# ---

# %% [markdown]
# ## 第一節 (W3-S1)：告別複製貼上 (For 迴圈基礎) (45 分鐘)

# %% [markdown]
# ### 👨‍🏫 教學過程細節與引導話術

# %% [markdown]
# * **0-15 min：工程師的美德是「懶惰」**
# * **老師操作**：在黑板上寫下要印出 1 到 100 的數字。
# * **引導話術**：「如果老闆叫你印出 1 到 100，難道你要寫 100 行 `print()` 嗎？真正的工程師是很懶惰的，只要是重複超過兩次的事情，我們一律交給『For 迴圈』這個輸送帶機器人來做！」
#
#
# * **15-30 min：認識數列製造機 `range()**`
# * **引導話術**：「自然組的同學對『等差數列』一定不陌生。Python 裡有一個製造數列的機器叫 `range(起點, 終點, 間距)`。注意喔！Python 的終點是不包含的，就像你搭電梯到 5 樓，其實你只爬了 4 層樓的高度。」
#
#
# * **30-45 min：科技感濾鏡 (CCTV 掃描線挑戰)**
# [這裡可以讓學生想像監視器畫面的橫向條紋]
# * **老師操作**：示範如何在圖片上畫出一條水平線。
# * **引導話術**：「上週我們手動畫了一個方塊，今天我們要用迴圈，每隔 50 個像素就自動畫一條綠色橫線，讓這張圖片瞬間變成像駭客任務或監視器的『掃描線濾鏡』！請大家挑戰把 `???` 填上。」

# %% [markdown]
# ### 💻 學生版 Colab 講義程式碼 (W3-S1)
#
# *(請複製以下內容至 Colab，學生需自行思考並填寫 `???`)*

# %%
# 這對嗎?
#如果 印出 1 到 100 的數字，哪就不能打遊戲了!!生命不是如此玩!!
print(f"現在的數字是：0")
print(f"現在的數字是：1")
print(f"現在的數字是：2")
print(f"現在的數字是：3")
print(f"現在的數字是：4")
for i in range( 0 , 101): # range(起點, 終點) 會產生一個從『起點』開始，到『終點前一個』為止的數字序列
    print(f"現在的數字是：{i}") # 把目前拿到的數字 i 印出來
# Out:
# 現在的數字是：0
# 現在的數字是：1
# 現在的數字是：2
# 現在的數字是：3
# 現在的數字是：4
# 現在的數字是：0
# 現在的數字是：1
# 現在的數字是：2
# 現在的數字是：3
# 現在的數字是：4
# 現在的數字是：5
# 現在的數字是：6
# 現在的數字是：7
# 現在的數字是：8
# 現在的數字是：9
# 現在的數字是：10
# 現在的數字是：11
# 現在的數字是：12
# 現在的數字是：13
# 現在的數字是：14
# 現在的數字是：15
# 現在的數字是：16
# 現在的數字是：17
# 現在的數字是：18
# 現在的數字是：19
# 現在的數字是：20
# 現在的數字是：21
# 現在的數字是：22
# 現在的數字是：23
# 現在的數字是：24
# 現在的數字是：25
# 現在的數字是：26
# 現在的數字是：27
# 現在的數字是：28
# 現在的數字是：29
# 現在的數字是：30
# 現在的數字是：31
# 現在的數字是：32
# 現在的數字是：33
# 現在的數字是：34
# 現在的數字是：35
# 現在的數字是：36
# 現在的數字是：37
# 現在的數字是：38
# 現在的數字是：39
# 現在的數字是：40
# 現在的數字是：41
# 現在的數字是：42
# 現在的數字是：43
# 現在的數字是：44
# 現在的數字是：45
# 現在的數字是：46
# 現在的數字是：47
# 現在的數字是：48
# 現在的數字是：49
# 現在的數字是：50
# 現在的數字是：51
# 現在的數字是：52
# 現在的數字是：53
# 現在的數字是：54
# 現在的數字是：55
# 現在的數字是：56
# 現在的數字是：57
# 現在的數字是：58
# 現在的數字是：59
# 現在的數字是：60
# 現在的數字是：61
# 現在的數字是：62
# 現在的數字是：63
# 現在的數字是：64
# 現在的數字是：65
# 現在的數字是：66
# 現在的數字是：67
# 現在的數字是：68
# 現在的數字是：69
# 現在的數字是：70
# 現在的數字是：71
# 現在的數字是：72
# 現在的數字是：73
# 現在的數字是：74
# 現在的數字是：75
# 現在的數字是：76
# 現在的數字是：77
# 現在的數字是：78
# ...

# %%
print("--- 任務 1：印出 0 到 4 ---")
# 👇 請將 ??? 填入正確的數字 (提示：終點是不包含的！就像電梯到五樓，只爬了四層樓)
# 這個 for 迴圈就像一個「自動印出機」
# 它會從 range() 裡面拿數字出來，然後每次拿一個就執行一次下面的 print 語句
for i in range( 0 , 5 ): # range(起點, 終點) 會產生一個從『起點』開始，到『終點前一個』為止的數字序列
    print(f"現在的數字是：{i}") # 把目前拿到的數字 i 印出來
# Out:
# --- 任務 1：印出 0 到 4 ---
# 現在的數字是：0
# 現在的數字是：1
# 現在的數字是：2
# 現在的數字是：3
# 現在的數字是：4

# %%
# ==========================================
# W3-S1 區塊 1：輸送帶機器人 (For 迴圈與 range)
# ==========================================
# 老師說：range(起點, 終點, 間隔) 就是等差數列製造機！


print("\n--- 任務 2：印出 10, 20, 30, 40, 50 ---")
# 👇 請利用 range 的「間隔(step)」功能來完成
# range(起點, 終點, 間隔) 可以讓數字跳著產生
# 想像你在跳格子，從哪格開始，跳到哪格停止，每次跳幾格
for j in range( 10 , 51 , 10 ): # 這個迴圈的目標是印出 10, 20, 30, 40, 50。想想起點、終點和間隔應該是多少？
    print(f"跳躍的數字：{j}") # 印出目前跳到的數字 j
# Out:
# --- 任務 2：印出 10, 20, 30, 40, 50 ---
# 跳躍的數字：10
# 跳躍的數字：20
# 跳躍的數字：30
# 跳躍的數字：40
# 跳躍的數字：50

# %%
# ==========================================
# W3-S1 區塊 2：🏆 課堂挑戰 (CCTV 掃描線濾鏡)
# ==========================================
import cv2 # 這是用來處理圖片的函式庫，就像一個圖片編輯軟體
from google.colab.patches import cv2_imshow # 這是讓 Colab 可以顯示圖片的工具

# 1. 準備乾淨的圖片
# 從網路上下載一張圖片
# !wget -q -O test.jpg https://raw.githubusercontent.com/ultralytics/yolov5/master/data/images/zidane.jpg
img = cv2.imread('test.jpg') # 讀取這張圖片到變數 img 裡面
height = img.shape[0] # 抓出圖片的總高度 (例如：720 像素)
width = img.shape[1]  # 抓出圖片的總寬度 (例如：1280 像素)

# 任務：我們希望從最上面 (Y=0) 開始，每隔 50 個像素，畫一條厚度為 2 的「綠色」水平線。
# 這樣整張圖就會佈滿橫線，看起來像監視器畫面！

# 👇 請完成下方的迴圈設定 👇
# 提示 1：y 是高度座標，範圍應該是從 0 到 圖片總高度 (height)。
# 提示 2：每隔 50 畫一條，所以「間隔」是 50。

# 這個迴圈會控制我們在圖片的哪個『高度』畫線
for y in range( 0 , height , 50 ): # 想想看，我們要從哪個高度開始 (起點)，到哪個高度結束 (終點，不包含)，每次跳多少像素 (間隔)？
    # 這行程式碼的意思：Y座標從 y 到 y+2 (代表這條線的厚度是 2 像素)，X座標 [:] 代表整條線橫跨圖片的寬度！
    # img[ Y 的範圍 , X 的範圍 ] 就是選取圖片上的某個區域
    # 等號右邊 (B, G, R) 是顏色的數值。B 是藍色，G 是綠色，R 是紅色。每個顏色從 0 到 255。
    # 👇 請把綠色的 (B, G, R) 填進去 👇
    img[ y : y+2 , : ] = ( 255 , 0 , 0 ) # 把選取的區域塗上你指定的顏色

for x in range( 0 , width , 50 ): # 想想看，我們要從哪個高度開始 (起點)，到哪個高度結束 (終點，不包含)，每次跳多少像素 (間隔)？
    # 這行程式碼的意思：X座標從 x 到 x+2 (代表這條線的厚度是 2 像素)，Y座標 [:] 代表整條線橫跨圖片的寬度！
    # img[ Y 的範圍 , X 的範圍 ] 就是選取圖片上的某個區域
    # 等號右邊 (B, G, R) 是顏色的數值。B 是藍色，G 是綠色，R 是紅色。每個顏色從 0 到 255。
    # 👇 請把綠色的 (B, G, R) 填進去 👇
    img[  :  , x :x+2 ] = ( 0 , 0 , 255 ) # 把選取的區域塗上你指定的顏色

# 顯示充滿科技感的結果！
print("\n--- 掃描線濾鏡啟動 ---")
cv2_imshow(img) # 顯示處理後的圖片
# Out:
# --- 掃描線濾鏡啟動 ---
# <PIL.Image.Image image mode=RGB size=1280x720>

# %% [markdown]
# ---
#
# ## 第二節 (W3-S2)：進階空間控制 (雙層迴圈與打碼) (45 分鐘)

# %% [markdown]
# ### 👨‍🏫 教學過程細節與引導話術

# %% [markdown]
# * **0-15 min：降維打擊 (雙層迴圈概念)**
# * **引導話術**：「如果你要在一塊空地種樹，你會怎麼種？你會先『走完第一排』，再退回原點『走第二排』。這就是迴圈包迴圈（Nested Loops）的概念。外層迴圈控制 Y (高度/排)，內層迴圈控制 X (寬度/格)！」
#
#
# * **15-30 min：IndexError 陣列越界危機**
# * **老師操作**：故意將迴圈範圍寫超過圖片大小，製造 `IndexError`。
# * **引導話術**：「這是寫 AI 影像處理最常遇到的『致命錯誤』！圖片明明只有 720 高，你的迴圈卻叫電腦去改第 800 列的顏色，電腦就會崩潰跳出 `IndexError: index out of bounds`。看到這個錯誤，第一件事就是去檢查你的 `range` 有沒有寫超過 `shape`！」
#
#
# * **30-45 min：終極 Boss 戰 (點陣網格/馬賽克雛形)**
# * **引導話術**：「我們現在要在畫面上，每隔 100 像素點上一個紅色的準星點。這需要 Y 軸跟 X 軸的迴圈一起配合。請完成講義裡的雙層迴圈挑戰！」

# %% [markdown]
# ### 💻 學生版 Colab 講義程式碼 (W3-S2)

# %%
# ==========================================
# W3-S2 區塊 1：🏆 雙層迴圈挑戰 (雷達定位點)
# ==========================================
# 任務：在圖片上，每隔 100 個像素的高度與寬度，畫一個 10x10 的「紅色」小方塊。
# 成果看起來會像是一張佈滿紅色定位點的網格圖！

# 重新讀取乾淨圖片 (確保每次執行都是在原圖上畫)
img_grid = cv2.imread('test.jpg')
h = img_grid.shape[0] # 圖片總高度
w = img_grid.shape[1] # 圖片總寬度

# 👇 請完成「雙層迴圈」的設定 👇
# 雙層迴圈就像在棋盤上走動：外層迴圈走『列』(Y軸)，內層迴圈走『行』(X軸)。
# 外層迴圈控制高度 (Y)，從 0 到 h，間隔 100
for y in range( 0 , height , 100 ): # 從高度 0 開始，到圖片最高點 h 為止，每隔 100 像素畫一排

    # 內層迴圈控制寬度 (X)，從 0 到 w，間隔 100
    # 注意這裡有縮排喔！代表這個迴圈是『外層迴圈裡面』的迴圈
    for x in range( 0 , w , 100 ): # 從寬度 0 開始，到圖片最寬點 w 為止，每隔 100 像素畫一個小方塊

        # 畫出 10x10 的紅色小方塊
        # 💡 防呆機制：如果 y+10 或 x+10 超過圖片邊界，會引發 IndexError！ (程式會說你超出範圍了！)
        # 但因為我們間隔是 100，所以剛好可以避開邊緣爆炸 (因為每次跳 100 像素，所以不會畫到圖片外面去)。
        # img[ Y 的起始點 : Y 的結束點 , X 的起始點 : X 的結束點 ] = 顏色
        # 👇 請填入正確的顏色數值 (B, G, R) 👇
        img_grid[ y : y+20 , x : x+20 ] = ( 225 , 0 , 0 ) # 在目前 (x, y) 的位置畫一個 10x10 的紅色方塊

print("\n--- 雷達定位點繪製完成 ---")
cv2_imshow(img_grid) # 顯示佈滿定位點的圖片
# Out:
# --- 雷達定位點繪製完成 ---
# <PIL.Image.Image image mode=RGB size=1280x720>

# %% [markdown]
# ---
#
# ## 📝 課後收斂：學習心得與「自我學習」反思 (W3 專屬版本)
#
# 這是本週最重要的一環。隨著程式越來越複雜（從一兩行變成雙層迴圈），學生遇到 Bug 的機率會大幅提升。我們必須在這個階段，將他們的挫折感轉化為「工程師的解題魂」。

# %%
# ==========================================
# 📝 第三週：工程師的修煉與自我反思 (存檔前必做！)
# ==========================================
print("【第一部分：迴圈空間思維】\n")

# 問題 1：數學與程式的結合
q1 = input("1. 今天我們用 range() 製造等差數列來畫線。你覺得『數學邏輯』對寫程式控制畫面有幫助嗎？為什麼？\n你的回答：")

print("\n------------------------------------------")
print("【第二部分：自我學習與除錯 (Debugging) 的覺醒】\n")
print("老師的話：")
print("寫程式最珍貴的能力，不是『背下所有的語法』，而是『解決未知的錯誤』。")
print("未來當你遇到 IndexError（超過邊界）或 SyntaxError（語法錯誤）時，老師可能不在旁邊。")
print("面對報錯的紅字，真正的駭客會感到興奮，因為那代表有新的問題等著被破解。\n")

# 問題 2：自我學習的策略
print("💡 提示工具箱：\n A. 複製錯誤訊息去 Google 搜尋。\n B. 把程式碼貼給 ChatGPT / Gemini，請 AI 解釋哪裡寫錯。\n C. 回頭一行一行檢查自己的邏輯與變數名稱。")
q2 = input("\n2. 當你下一次程式碼跑出一大堆紅字 (Error) 時，你決定第一步要先做什麼？(可參考上方提示或寫自己的方法)\n你的回答：")

# 問題 3：心態設定
q3 = input("\n3. 給未來的自己一句話：當程式怎麼跑都不對、覺得很煩躁時，你要怎麼提醒自己冷靜下來？\n你的回答：")

print("\n==========================================")
print(f"🌟 恭喜你，你的除錯意志已升級！")
print("記住你的承諾：遇到紅字先深呼吸，然後善用 Google 與 AI 當你的自學助教。")
print("==========================================")
print("🚨 【重要提醒】：請點選左上角「檔案」->「在雲端硬碟中儲存副本」，把這份筆記存下來！下週見！")

# %% [markdown]
# ### 👨‍🏫 給老師的課堂特別叮嚀：引導自我學習的 3 個心法
#
# 在課程尾聲，您可以將學生的目光從螢幕拉回講台，用這幾句話作為結語，強化他們對自我學習的認知：
#
# 1. **「Google 是最資深的前輩」**：告訴學生，全世界最高薪的軟體工程師，每天上班也在 Google 查語法。忘記語法不可恥，**不知道怎麼下關鍵字搜尋才危險**。鼓勵他們將錯誤訊息（例如 `IndexError Python 陣列`）直接拿去搜尋。
# 2. **「AI 是你的專屬家教，不是代寫機器」**：提醒學生，如果把有問題的程式碼丟給 AI，不要只複製 AI 給的正確答案。要對 AI 說：**「請告訴我，我原本錯在哪裡？為什麼？」** 這樣才是把 AI 當作自我學習的槓桿。
# 3. **「程式碼的盡頭是數學與邏輯」**：強調自然組的優勢在於理科邏輯。迴圈怎麼繞、座標怎麼算，這背後都是數學。語法（Python/C++）會隨時代被淘汰，但「把複雜問題拆解成迴圈步驟」的邏輯思維，是一輩子帶得走的能力。

# %% [markdown]
# ---
#
# # 學習心得
#
# 1.   心得:
#
#     這週的課程讓我對程式設計的核心概念有了更深入的理解。從一開始複習變數（X, Y）和基本的邏輯判斷（`if else`），我學習到程式如何根據條件做出決策。最令人印象深刻的是 `for` 迴圈和 `range()` 的應用，它完美地詮釋了「工程師的懶惰美德」。過去需要手動重複的操作，現在只需要簡單幾行程式碼就能自動完成，極大地提升了效率。
#
#     特別是在圖像處理的練習中，透過單層迴圈實現「掃描線濾鏡」和雙層迴圈實現「雷達定位點」，讓我親身體驗到迴圈在處理二維空間問題上的強大之處。理解 `range()` 的「起點、終點（不包含）、間隔」是關鍵，這讓我能精確控制迴圈的行為，並在圖片上繪製出我想要的效果。
#
#     此外，課程中也強調了除錯（Debugging）的重要性。面對 `IndexError` 等錯誤時，不再感到手足無措，而是將其視為學習的機會。我學會了如何利用 Google 和 AI 工具作為自我學習的助教，去理解錯誤訊息、找出問題的根源，而不是僅僅複製貼上解決方案。這種解決問題的心態和能力，才是程式設計中最寶貴的財富。
#
#     總之，這週我不僅學會了 `for` 迴圈和 `range()` 的使用，更重要的是培養了自動化思維、空間邏輯推理能力，以及遇到問題時獨立除錯和自我學習的工程師精神。我期待未來能將這些能力應用到更多有趣的專案中。
